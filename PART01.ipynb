# %%
#

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab_Notebooks/Study/OpenCV-Python
# Out:
# /content/drive/MyDrive/Colab_Notebooks/Study/OpenCV-Python

# %%
# !git add PART01.ipynb
# Out:
# fatal: pathspec 'PART01.ipynb' did not match any files
