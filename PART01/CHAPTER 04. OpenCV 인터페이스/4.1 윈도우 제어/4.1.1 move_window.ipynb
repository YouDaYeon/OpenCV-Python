# %% [markdown]
# ❌ Colab에서는 cv2.namedWindow()를 사용할 수 없음!
#
# Colab에서도 OpenCV를 사용해서 이미지를 처리하고 표시하는 방법
#
# 👉 cv2.imshow() 대신 matplotlib을 사용

# %%
# 넘파이 라이브러리 임포트
# OpenCV 라이브러리 임포트

# 행렬 생성
# 밝은 회색(200) 바탕 영상 생성

# 윈도우 이름
# 윈도우 생성 및 크기 조정 옵션

# 윈도우 이동 - 위치 지정

# 행렬 원소를 영상으로 표시

# 키 이벤트(key event) 대기
# 열린 모든 윈도우 파괴

# %%
import numpy as np
import cv2

# 행렬 생성
# 밝은 회색(200) 바탕 영상 생성
image = np.zeros((200, 400), np.unit8)
image[:] = 200

# 윈도우 이름
# 윈도우 생성 및 크기 조정 옵션
title1, title2 = 'Position1', 'Position2'
cv2.namedWindow(title1, cv2.WINDOW_AUTOSIZE)
cv2.namedWindow(title2)

# 윈도우 이동 - 위치 지정
cv2.moveWindow(title1, 150, 150) # 모니터의 150, 150 위치에 윈도우 위치
cv2.moveWindwo(title2, 400, 50) # 모니터의 400, 50 위치에 윈도우 위치

# 행렬 원소를 영상으로 표시
cv2.imshow(title1, image)
cv2.imshow(title2, image)

# 키 이벤트(key event) 대기
cv2.waitKey(0)
# 열린 모든 윈도우 파괴
cv2.destroyAllWindows()

# %% [markdown]
# > Colab용 수정된 코드

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# 밝은 회색(200) 바탕의 영상 생성
image = np.zeros((200, 400), dtype=np.uint8)  # uint8로 변경
image[:] = 200

# %% [markdown]
# **👉 uint8은 이미지를 표현하는 표준 데이터 타입(0~255)**
#
# np.zeros()는 기본적으로 float64 타입으로 배열을 생성한다.
#
# 하지만, OpenCV에서는 이미지 데이터가 반드시 unit8 타입이어야 한다.

# %%
image
# Out:
# array([[200, 200, 200, ..., 200, 200, 200],
#        [200, 200, 200, ..., 200, 200, 200],
#        [200, 200, 200, ..., 200, 200, 200],
#        ...,
#        [200, 200, 200, ..., 200, 200, 200],
#        [200, 200, 200, ..., 200, 200, 200],
#        [200, 200, 200, ..., 200, 200, 200]], dtype=uint8)

# %%
# Colab에서는 cv2.imshow() 대신 matplotlib을 사용해서 이미지 출력
plt.figure(figsize=(6, 3))  # 윈도우 크기 조절 효과
plt.imshow(image, cmap='gray')  # 흑백 이미지 출력
plt.title('Position1')
plt.axis('off')  # 축 숨기기
plt.show()
